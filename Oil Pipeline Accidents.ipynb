# %% [markdown]
# # Oil Pipeline Accidents

# %% [markdown]
# ## Business Problem

# %% [markdown]
# This database includes a record for each oil pipeline leak or spill reported to the Pipeline and Hazardous Materials Safety Administration since 2010. These records include the incident date and time, operator and pipeline, cause of incident, type of hazardous liquid and quantity lost, injuries and fatalities, and associated costs.

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# The oil pipeline accident reports were collected and published by the DOT's Pipeline and Hazardous Materials Safety Administration.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %%
df = pd.read_csv('database.csv')
df.head()
# Out:
#    Report Number  Supplemental Number  Accident Year Accident Date/Time  \
# 0       20100016                17305           2010   1/1/2010 7:15 AM
# 1       20100254                17331           2010   1/4/2010 8:30 AM
# 2       20100038                17747           2010  1/5/2010 10:30 AM
# 3       20100260                18574           2010   1/6/2010 7:30 PM
# 4       20100030                16276           2010   1/7/2010 1:00 PM
#
#    Operator ID                         Operator Name Pipeline/Facility Name  \
# 0        32109                 ONEOK NGL PIPELINE LP      KINDER MORGAN JCT
# 1        15786                PORTLAND PIPELINE CORP      24-INCH MAIN LINE
# 2        20160           PETROLOGISTICS OLEFINS, LLC                    NaN
# 3        11169  ENBRIDGE ENERGY, LIMITED PARTNERSHIP      SUPERIOR TERMINAL
# 4          300                 PLAINS PIPELINE, L.P.         RED RIVER EAST
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2795 entries, 0 to 2794
# Data columns (total 48 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Report Number                         2795 non-null   int64
#  1   Supplemental Number                   2795 non-null   int64
#  2   Accident Year                         2795 non-null   int64
#  3   Accident Date/Time                    2795 non-null   object
#  4   Operator ID                           2795 non-null   int64
#  5   Operator Name                         2795 non-null   object
#  6   Pipeline/Facility Name                2674 non-null   object
#  7   Pipeline Location                     2795 non-null   object
#  8   Pipeline Type                         2777 non-null   object
#  9   Liquid Type                           2795 non-null   object
#  10  Liquid Subtype                        1349 non-null   object
# ...

# %%
# Visualize the number of missing
# values as a bar chart
msno.bar(df);

# %%
df.drop(columns=['Operator Employee Injuries', 'Operator Contractor Injuries',
                 'Emergency Responder Injuries','Other Injuries','Public Injuries','All Injuries',
                 'All Fatalities','Operator Employee Fatalities','Operator Contractor Fatalities',
                 'Emergency Responder Fatalities','Other Fatalities','Public Fatalities','All Fatalities'], inplace=True)

# %%
df.head()
# Out:
#    Report Number  Supplemental Number  Accident Year Accident Date/Time  \
# 0       20100016                17305           2010   1/1/2010 7:15 AM
# 1       20100254                17331           2010   1/4/2010 8:30 AM
# 2       20100038                17747           2010  1/5/2010 10:30 AM
# 3       20100260                18574           2010   1/6/2010 7:30 PM
# 4       20100030                16276           2010   1/7/2010 1:00 PM
#
#    Operator ID                         Operator Name Pipeline/Facility Name  \
# 0        32109                 ONEOK NGL PIPELINE LP      KINDER MORGAN JCT
# 1        15786                PORTLAND PIPELINE CORP      24-INCH MAIN LINE
# 2        20160           PETROLOGISTICS OLEFINS, LLC                    NaN
# 3        11169  ENBRIDGE ENERGY, LIMITED PARTNERSHIP      SUPERIOR TERMINAL
# 4          300                 PLAINS PIPELINE, L.P.         RED RIVER EAST
#
# ...

# %%
df.shape
# Out:
# (2795, 36)

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# ### Missing Values

# %% [markdown]
# #### Liquid Name

# %%
df['Liquid Name'].value_counts().count()
# Out:
# 69

# %%
df['Liquid Name'].isna().value_counts()
# Out:
# True     2573
# False     222
# Name: Liquid Name, dtype: int64

# %%
liquid = df.groupby('Liquid Name')['Liquid Type'].value_counts().unstack()
liquid
# Out:
# Liquid Type                               HVL OR OTHER FLAMMABLE OR TOXIC FLUID, GAS  \
# Liquid Name
# (LCO) LIGHT CYCLE OIL                                                            NaN
# 14# NATURAL GASOLINE                                                             1.0
# 98.7% ETHANE, .97% METHANE, .36% PROPANE                                         1.0
# ACETIC ACID                                                                      NaN
# ATMOSPHERIC GAS OIL                                                              NaN
# ...                                                                              ...
# VACUUM GAS OIL (VGO)                                                             NaN
# VINYL ACETATE MONOMER                                                            NaN
# Y GRADE                                                                          3.0
# Y-GRADE                                                                         23.0
# ...

# %% [markdown]
# ### Outliers in geographical locations

# %%
sns.scatterplot(x='Accident Longitude', y='Accident Latitude', data = df)
# Out:
# <AxesSubplot:xlabel='Accident Longitude', ylabel='Accident Latitude'>

# %%
to_drop = df.loc[(df['Accident Longitude'] > -50) | (df['Accident Latitude'] < 20)]

# %%
df.drop(to_drop.index, axis=0, inplace=True)

# %%
sns.scatterplot(x='Accident Longitude', y='Accident Latitude', data = df)
# Out:
# <AxesSubplot:xlabel='Accident Longitude', ylabel='Accident Latitude'>

# %%
df.rename(columns={'Accident Latitude' : 'Latitude', 'Accident Longitude' : 'Longitude'}, inplace=True)

# %%
df.head()
# Out:
#    Report Number  Supplemental Number  Accident Year Accident Date/Time  \
# 0       20100016                17305           2010   1/1/2010 7:15 AM
# 1       20100254                17331           2010   1/4/2010 8:30 AM
# 2       20100038                17747           2010  1/5/2010 10:30 AM
# 3       20100260                18574           2010   1/6/2010 7:30 PM
# 4       20100030                16276           2010   1/7/2010 1:00 PM
#
#    Operator ID                         Operator Name Pipeline/Facility Name  \
# 0        32109                 ONEOK NGL PIPELINE LP      KINDER MORGAN JCT
# 1        15786                PORTLAND PIPELINE CORP      24-INCH MAIN LINE
# 2        20160           PETROLOGISTICS OLEFINS, LLC                    NaN
# 3        11169  ENBRIDGE ENERGY, LIMITED PARTNERSHIP      SUPERIOR TERMINAL
# 4          300                 PLAINS PIPELINE, L.P.         RED RIVER EAST
#
# ...
